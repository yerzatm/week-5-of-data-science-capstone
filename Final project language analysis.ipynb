# %%
import pandas as pd

# %%
df=pd.read_csv("2016_neighbourhood_profiles.csv", encoding='unicode_escape')

# %%
df1=df.transpose()

# %%
header_names=list(df)

# %%
header_names.remove('City of Toronto')

# %%
header_names
# Out:
# ['Category',
#  'Topic',
#  'Data Source',
#  'Characteristic',
#  'Agincourt North',
#  'Agincourt South-Malvern West',
#  'Alderwood',
#  'Annex',
#  'Banbury-Don Mills',
#  'Bathurst Manor',
#  'Bay Street Corridor',
#  'Bayview Village',
#  'Bayview Woods-Steeles',
#  'Bedford Park-Nortown',
#  'Beechborough-Greenbrook',
#  'Bendale',
#  'Birchcliffe-Cliffside',
#  'Black Creek',
#  'Blake-Jones',
#  'Briar Hill-Belgravia',
#  'Bridle Path-Sunnybrook-York Mills',
#  'Broadview North',
#  'Brookhaven-Amesbury',
#  'Cabbagetown-South St. James Town',
#  'Caledonia-Fairbank',
#  'Casa Loma',
#  'Centennial Scarborough',
#  'Church-Yonge Corridor',
#  'Clairlea-Birchmount',
#  'Clanton Park',
#  'Cliffcrest',
#  'Corso Italia-Davenport',
#  'Danforth',
#  'Danforth East York',
#  'Don Valley Village',
#  'Dorset Park',
#  'Dovercourt-Wallace Emerson-Junction',
#  'Downsview-Roding-CFB',
#  'Dufferin Grove',
#  'East End-Danforth',
#  'Edenbridge-Humber Valley',
#  'Eglinton East',
# ...

# %%
rank=pd.read_csv('Neighborhoods rank by venues.csv')

# %%
rank.sort_values('Venue', ascending=False)
# Out:
#                                          Neighborhood  Neighborhood Latitude  \
# 0                              Adelaide,King,Richmond                    100
# 20            Chinatown,Grange Park,Kensington Market                    100
# 82                                     St. James Town                    100
# 79                            Ryerson,Garden District                    100
# 44              First Canadian Place,Underground city                    100
# ..                                                ...                    ...
# 76                                           Roselawn                      1
# 94                                             Weston                      1
# 26  Cloverdale,Islington,Martin Grove,Princess Gar...                      1
# 68                             Newtonbrook,Willowdale                      1
# 42                                    Emery,Humberlea                      1
#
# ...

# %%
chinese=df.loc[[357]]
chinese.head()
# Out:
#      Category          Topic                     Data Source  \
# 357  Language  Mother tongue  Census Profile 98-316-X2016001
#
#                   Characteristic City of Toronto Agincourt North  \
# 357            Chinese languages         245,285          14,670
#
#     Agincourt South-Malvern West Alderwood  Annex Banbury-Don Mills  ...  \
# 357                        9,935       190  1,530             3,430  ...
#
#     Willowdale West Willowridge-Martingrove-Richview Woburn Woodbine Corridor  \
# 357           3,090                              380  3,195               655
#
#     Woodbine-Lumsden Wychwood Yonge-Eglinton Yonge-St.Clair  \
# 357              565      580            430            295
#
#     York University Heights Yorkdale-Glen Park
# 357                   1,570                650
#
# [1 rows x 145 columns]

# %%
dflang.head(3)
# Out:
#      Category          Topic                     Data Source  \
# 139  Language  Mother tongue  Census Profile 98-316-X2016001
# 140  Language  Mother tongue  Census Profile 98-316-X2016001
# 141  Language  Mother tongue  Census Profile 98-316-X2016001
#
#                                         Characteristic City of Toronto  \
# 139  Mother tongue for the total population excludi...       2,704,415
# 140                                   Single responses       2,598,230
# 141                                 Official languages       1,411,345
#
#     Agincourt North Agincourt South-Malvern West Alderwood   Annex  \
# 139          28,845                       23,740    12,035  29,880
# 140          27,740                       22,720    11,675  29,110
# 141           7,185                        7,215     7,465  21,355
#
#     Banbury-Don Mills  ... Willowdale West Willowridge-Martingrove-Richview  \
# 139            27,480  ...          16,890                           22,150
# ...

# %%
dfpoplangtor=dflang[['Characteristic',"City of Toronto"]]
dfpoplangtor
# Out:
#                                         Characteristic City of Toronto
# 139  Mother tongue for the total population excludi...       2,704,415
# 140                                   Single responses       2,598,230
# 141                                 Official languages       1,411,345
# 142                                            English       1,375,905
# 143                                             French          35,440
# ..                                                 ...             ...
# 387                                 Multiple responses         106,190
# 388                                 English and French           7,550
# 389                  English and non-official language          92,620
# 390                   French and non-official language           3,300
# 391          English, French and non-official language           2,715
#
# [253 rows x 2 columns]

# %%
chinesefinal = chinesetransposed.iloc[4:]

# %%
chinesetransposed=chinese.transpose()
chinesetransposed.head(10)
# Out:
#                                                          357
# Category                                            Language
# Topic                                          Mother tongue
# Data Source                   Census Profile 98-316-X2016001
# Characteristic                             Chinese languages
# City of Toronto                                      245,285
# Agincourt North                                       14,670
# Agincourt South-Malvern West                           9,935
# Alderwood                                                190
# Annex                                                  1,530
# Banbury-Don Mills                                      3,430

# %%
chineserating=chinesetransposed.sort_values(by="357", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-fc9138de5dbd> in <module>
# ----> 1 chineserating=chinesetransposed.sort_values(by="357", ascending=False)
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4986
#    4987             by = by[0]
# -> 4988             k = self._get_label_or_level_values(by, axis=axis)
#    4989
#    4990             if isinstance(ascending, (tuple, list)):
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1773             values = self.axes[axis].get_level_values(key)._values
#    1774         else:
# -> 1775             raise KeyError(key)
#    1776
#    1777         # Check for duplicates
#
# KeyError: '357'

# %%
dfpoplangtor=dflang[['Characteristic',"Regent Park"]]

# %%
chinesefinal.columns=['chinese']
chinesefinal.head()
# Out:
#                               chinese
# City of Toronto               245,285
# Agincourt North                14,670
# Agincourt South-Malvern West    9,935
# Alderwood                         190
# Annex                           1,530

# %%
aa=chinesefinal["chinese"].str.replace(",","",).astype(float)
aa
# Out:
# City of Toronto                 245285.0
# Agincourt North                  14670.0
# Agincourt South-Malvern West      9935.0
# Alderwood                          190.0
# Annex                             1530.0
#                                   ...
# Wychwood                           580.0
# Yonge-Eglinton                     430.0
# Yonge-St.Clair                     295.0
# York University Heights           1570.0
# Yorkdale-Glen Park                 650.0
# Name: chinese, Length: 141, dtype: float64

# %%
chineserating=chinesefinal.sort_values(by="aa", ascending=False)

# %%
chinesefinal['aa']=aa.values

# %%
chineserating
# Out:
#                           chinese        aa
# City of Toronto           245,285  245285.0
# Milliken                   16,510   16510.0
# Steeles                    15,655   15655.0
# Agincourt North            14,670   14670.0
# Willowdale East            14,455   14455.0
# ...                           ...       ...
# Humber Summit                 100     100.0
# Rustic                        100     100.0
# Maple Leaf                     95      95.0
# Humber Heights-Westmount       70      70.0
# Beechborough-Greenbrook        60      60.0
#
# [141 rows x 2 columns]

# %%
dflang=df[df["Topic"]=='Mother tongue']

# %%
a=dfpoplangtor["Regent Park"].str.replace(",","",).astype(float)

# %%
langrating=dfpoplangtor.sort_values(by="a", ascending=False)

# %%
dfpoplangtor['a']=a.values

# %%
langrating.head(50)
# Out:
#                                         Characteristic Regent Park        a
# 139  Mother tongue for the total population excludi...      10,690  10690.0
# 140                                   Single responses      10,190  10190.0
# 144                             Non-official languages       5,265   5265.0
# 212                           Non-Aboriginal languages       5,265   5265.0
# 141                                 Official languages       4,925   4925.0
# 142                                            English       4,695   4695.0
# 261                            Indo-European languages       2,270   2270.0
# 300                             Indo-Iranian languages       1,640   1640.0
# 301                               Indo-Aryan languages       1,470   1470.0
# 302                                            Bengali       1,160   1160.0
# 356                             Sino-Tibetan languages       1,105   1105.0
# ...

# %%
langrating = langrating.drop(langrating[langrating['Hillcrest Village']<100].index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hillcrest Village'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-40be6817dcbe> in <module>
# ...

# %%
langrating
# Out:
#                                         Characteristic City of Toronto  \
# 139  Mother tongue for the total population excludi...       2,704,415
# 140                                   Single responses       2,598,230
# 141                                 Official languages       1,411,345
# 142                                            English       1,375,905
# 144                             Non-official languages       1,186,885
# ..                                                 ...             ...
# 195                           Salish languages, n.i.e.               0
# 196                                   Siouan languages               0
# 354                               Quebec Sign Language               0
# 159                                    Dogrib (Tlicho)               0
# 194                             Thompson (Ntlakapamux)               0
#
#              a
# 139  2704415.0
# 140  2598230.0
# 141  1411345.0
# 142  1375905.0
# 144  1186885.0
# ..         ...
# ...
